# %%
## imports dependencies
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
## reads data file into python
data_file_path = os.path.join('..', 'raw_data', 'team_game_level_data.csv')
team_game_df = pd.read_csv(data_file_path)

# %%
## filter team_game_df down to just winners
winner_df = team_game_df[team_game_df['win'] == 1].copy()
winner_df['seed_diff'] = winner_df['seed'] - winner_df['opponent_seed']
winner_df['seed_diff'] = winner_df['seed'] - winner_df['opponent_seed']
winner_df['abs_seed_diff'] = abs(winner_df['seed_diff'])
winner_df
# Out:
#       game_id        date                  round     region  seed  \
# 0           0  1985-03-14            Round of 64       East     1
# 2           1  1985-03-14            Round of 64       East     4
# 4           2  1985-03-14            Round of 64       East     5
# 7           3  1985-03-14            Round of 64       East     8
# 9           4  1985-03-14            Round of 64    Midwest     1
# 11          5  1985-03-14            Round of 64    Midwest     4
# 12          6  1985-03-14            Round of 64    Midwest     5
# 15          7  1985-03-14            Round of 64    Midwest     9
# 17          8  1985-03-14            Round of 64  Southeast     2
# 19          9  1985-03-14            Round of 64  Southeast     3
# 20         10  1985-03-14            Round of 64  Southeast     7
# 23         11  1985-03-14            Round of 64  Southeast    11
# 25         12  1985-03-14            Round of 64       West     1
# 27         13  1985-03-14            Round of 64       West     4
# 28         14  1985-03-14            Round of 64       West     9
# 31         15  1985-03-14            Round of 64       West    12
# 32         16  1985-03-15            Round of 64       East     2
# 34         17  1985-03-15            Round of 64       East     3
# 36         18  1985-03-15            Round of 64       East     6
# 39         19  1985-03-15            Round of 64       East     7
# 41         20  1985-03-15            Round of 64    Midwest     2
# 42         21  1985-03-15            Round of 64    Midwest     3
# 45         22  1985-03-15            Round of 64    Midwest     7
# 46         23  1985-03-15            Round of 64    Midwest    11
# 49         24  1985-03-15            Round of 64  Southeast     1
# 50         25  1985-03-15            Round of 64  Southeast     5
# 52         26  1985-03-15            Round of 64  Southeast     8
# 54         27  1985-03-15            Round of 64  Southeast    13
# 57         28  1985-03-15            Round of 64       West     2
# 59         29  1985-03-15            Round of 64       West     3
# ...       ...         ...                    ...        ...   ...
# 4040     2020  2016-03-19            Round of 32       East     5
# 4042     2021  2016-03-19            Round of 32    Midwest     1
# 4044     2022  2016-03-19            Round of 32    Midwest     4
# 4047     2023  2016-03-19            Round of 32    Midwest    11
# 4048     2024  2016-03-19            Round of 32      South     1
# 4051     2025  2016-03-19            Round of 32      South     3
# 4052     2026  2016-03-19            Round of 32       West     4
# 4055     2027  2016-03-20            Round of 32       East     6
# 4056     2028  2016-03-20            Round of 32       East     7
# 4059     2029  2016-03-20            Round of 32    Midwest    10
# 4061     2030  2016-03-20            Round of 32      South     2
# 4063     2031  2016-03-20            Round of 32      South     5
# 4064     2032  2016-03-20            Round of 32       West     1
# 4067     2033  2016-03-20            Round of 32       West     2
# 4069     2034  2016-03-20            Round of 32       West     3
# 4071     2035  2016-03-24          Sweet Sixteen      South     1
# 4072     2036  2016-03-24          Sweet Sixteen      South     2
# 4075     2037  2016-03-24          Sweet Sixteen       West     1
# 4077     2038  2016-03-24          Sweet Sixteen       West     2
# 4079     2039  2016-03-25          Sweet Sixteen       East     1
# 4081     2040  2016-03-25          Sweet Sixteen       East     6
# 4083     2041  2016-03-25          Sweet Sixteen    Midwest     1
# 4085     2042  2016-03-25          Sweet Sixteen    Midwest    10
# 4087     2043  2016-03-26            Elite Eight      South     2
# 4088     2044  2016-03-26            Elite Eight       West     2
# 4091     2045  2016-03-27            Elite Eight       East     1
# 4093     2046  2016-03-27            Elite Eight    Midwest    10
# 4095     2047  2016-04-02    National Semifinals        NaN     1
# 4097     2048  2016-04-02    National Semifinals        NaN     2
# 4098     2049  2016-04-04  National Championship        NaN     2
#
#                        team  score  opponent_seed                    opponent  \
# 0                Georgetown     68             16                      Lehigh
# 2          Loyola, Illinois     59             13                        Iona
# 4        Southern Methodist     85             12                Old Dominion
# 7                    Temple     60              9               Virginia Tech
# 9                  Oklahoma     96             16          North Carolina A&T
# 11               Ohio State     75             13                  Iowa State
# 12           Louisiana Tech     78             12                  Pittsburgh
# 15           Illinois State     58              8         Southern California
# 17           North Carolina     76             15      Middle Tennessee State
# 19                   Kansas     49             14                        Ohio
# 20               Notre Dame     79             10                Oregon State
# 23                   Auburn     59              6                      Purdue
# 25     St. John's, New York     83             16                    Southern
# 27         Nevada-Las Vegas     85             13             San Diego State
# 28                 Arkansas     63              8                        Iowa
# 31                 Kentucky     66              5                  Washington
# 32             Georgia Tech     65             15                      Mercer
# 34                 Illinois     76             14                Northeastern
# 36                  Georgia     67             11               Wichita State
# 39                 Syracuse     70             10                      DePaul
# 41                  Memphis     67             15                Pennsylvania
# 42                     Duke     75             14                  Pepperdine
# 45                      UAB     70             10              Michigan State
# 46           Boston College     55              6                  Texas Tech
# 49                 Michigan     59             16         Fairleigh Dickinson
# 50                 Maryland     69             12                 Miami, Ohio
# 52                Villanova     51              9                      Dayton
# 54                     Navy     78              4             Louisiana State
# 57    Virginia Commonwealth     81             15                    Marshall
# 59     North Carolina State     65             14                      Nevada
# ...                     ...    ...            ...                         ...
# 4040                Indiana     73              4                    Kentucky
# 4042               Virginia     77              9                      Butler
# 4044             Iowa State     78             12        Arkansas-Little Rock
# 4047                Gonzaga     82              3                        Utah
# 4048                 Kansas     73              9                 Connecticut
# 4051         Miami, Florida     65             11               Wichita State
# 4052                   Duke     71             12                        Yale
# 4055             Notre Dame     76             14           Stephen F. Austin
# 4056              Wisconsin     66              2                Xavier, Ohio
# 4059               Syracuse     75             15      Middle Tennessee State
# 4061              Villanova     87              7                        Iowa
# 4063               Maryland     73             13                      Hawaii
# 4064                 Oregon     69              8  St. Joseph's, Pennsylvania
# 4067               Oklahoma     85             10       Virginia Commonwealth
# 4069              Texas A&M     92             11               Northern Iowa
# 4071                 Kansas     79              5                    Maryland
# 4072              Villanova     92              3              Miami, Florida
# 4075                 Oregon     82              4                        Duke
# 4077               Oklahoma     77              3                   Texas A&M
# 4079         North Carolina    101              5                     Indiana
# 4081             Notre Dame     61              7                   Wisconsin
# 4083               Virginia     84              4                  Iowa State
# 4085               Syracuse     63             11                     Gonzaga
# 4087              Villanova     64              1                      Kansas
# 4088               Oklahoma     80              1                      Oregon
# 4091         North Carolina     88              6                  Notre Dame
# 4093               Syracuse     68              1                    Virginia
# 4095         North Carolina     83             10                    Syracuse
# 4097              Villanova     95              2                    Oklahoma
# 4098              Villanova     77              1              North Carolina
#
#       opponent_score overtime  score_diff  win    seed_id  seed_diff  \
# 0                 43      NaN          25    1   1_16_fav        -15
# 2                 58      NaN           1    1   4_13_fav         -9
# 4                 68      NaN          17    1   5_12_fav         -7
# 7                 57      NaN           3    1    8_9_fav         -1
# 9                 83      NaN          13    1   1_16_fav        -15
# 11                64      NaN          11    1   4_13_fav         -9
# 12                54      NaN          24    1   5_12_fav         -7
# 15                55      NaN           3    1    8_9_dog          1
# 17                57      NaN          19    1   2_15_fav        -13
# 19                38      NaN          11    1   3_14_fav        -11
# 20                70      NaN           9    1   7_10_fav         -3
# 23                58      NaN           1    1   6_11_dog          5
# 25                59      NaN          24    1   1_16_fav        -15
# 27                80      NaN           5    1   4_13_fav         -9
# 28                54      NaN           9    1    8_9_dog          1
# 31                58      NaN           8    1   5_12_dog          7
# 32                58      NaN           7    1   2_15_fav        -13
# 34                57      NaN          19    1   3_14_fav        -11
# 36                59      NaN           8    1   6_11_fav         -5
# 39                65      NaN           5    1   7_10_fav         -3
# 41                55      NaN          12    1   2_15_fav        -13
# 42                62      NaN          13    1   3_14_fav        -11
# 45                68      NaN           2    1   7_10_fav         -3
# 46                53      NaN           2    1   6_11_dog          5
# 49                55      NaN           4    1   1_16_fav        -15
# 50                68     1 OT           1    1   5_12_fav         -7
# 52                49      NaN           2    1    8_9_fav         -1
# 54                55      NaN          23    1   4_13_dog          9
# 57                65      NaN          16    1   2_15_fav        -13
# 59                56      NaN           9    1   3_14_fav        -11
# ...              ...      ...         ...  ...        ...        ...
# 4040              67      NaN           6    1    4_5_dog          1
# 4042              69      NaN           8    1    1_9_fav         -8
# 4044              61      NaN          17    1   4_12_fav         -8
# 4047              59      NaN          23    1   3_11_dog          8
# 4048              61      NaN          12    1    1_9_fav         -8
# 4051              57      NaN           8    1   3_11_fav         -8
# 4052              64      NaN           7    1   4_12_fav         -8
# 4055              75      NaN           1    1   6_14_fav         -8
# 4056              63      NaN           3    1    2_7_dog          5
# 4059              50      NaN          25    1  10_15_fav         -5
# 4061              68      NaN          19    1    2_7_fav         -5
# 4063              60      NaN          13    1   5_13_fav         -8
# 4064              64      NaN           5    1    1_8_fav         -7
# 4067              81      NaN           4    1   2_10_fav         -8
# 4069              88     2 OT           4    1   3_11_fav         -8
# 4071              63      NaN          16    1    1_5_fav         -4
# 4072              69      NaN          23    1    2_3_fav         -1
# 4075              68      NaN          14    1    1_4_fav         -3
# 4077              63      NaN          14    1    2_3_fav         -1
# 4079              86      NaN          15    1    1_5_fav         -4
# 4081              56      NaN           5    1    6_7_fav         -1
# 4083              71      NaN          13    1    1_4_fav         -3
# 4085              60      NaN           3    1  10_11_fav         -1
# 4087              59      NaN           5    1    1_2_dog          1
# 4088              68      NaN          12    1    1_2_dog          1
# 4091              74      NaN          14    1    1_6_fav         -5
# 4093              62      NaN           6    1   1_10_dog          9
# 4095              66      NaN          17    1   1_10_fav         -9
# 4097              51      NaN          44    1        2_2          0
# 4098              74      NaN           3    1    1_2_dog          1
#
#       abs_seed_diff
# 0                15
# 2                 9
# 4                 7
# 7                 1
# 9                15
# 11                9
# 12                7
# 15                1
# 17               13
# 19               11
# 20                3
# 23                5
# 25               15
# 27                9
# 28                1
# 31                7
# 32               13
# 34               11
# 36                5
# 39                3
# 41               13
# 42               11
# 45                3
# 46                5
# 49               15
# 50                7
# 52                1
# 54                9
# 57               13
# 59               11
# ...             ...
# 4040              1
# 4042              8
# 4044              8
# 4047              8
# 4048              8
# 4051              8
# 4052              8
# 4055              8
# 4056              5
# 4059              5
# 4061              5
# 4063              8
# 4064              7
# 4067              8
# 4069              8
# 4071              4
# 4072              1
# 4075              3
# 4077              1
# 4079              4
# 4081              1
# 4083              3
# 4085              1
# 4087              1
# 4088              1
# 4091              5
# 4093              9
# 4095              9
# 4097              0
# 4098              1
#
# [2050 rows x 16 columns]

# %%
## Function to create scatter
def create_all_games_scatter(winner_df, title, absolute):
    if absolute == 'y':
        seed_diff_measure = 'abs_seed_diff'
    elif absolute == 'n':
        seed_diff_measure = 'seed_diff'
    plt.scatter(winner_df[seed_diff_measure], winner_df['score_diff'])
    plt.xlabel(seed_diff_measure.replace('_', ' '))
    plt.ylabel('point diff')
    plt.title(title)

# %%
## basic all games scatter
title = 'Score Differential vs Seed Diff'
create_all_games_scatter(winner_df, title, 'n')
plt.show()

# %%
## basic round 64 scatter
round_64_winner_df = winner_df[winner_df['round'] == 'Round of 64']
round_64_scatter_title = 'Round of 64 Score Differential vs Seed Diff'
create_all_games_scatter(round_64_winner_df, round_64_scatter_title, 'n')
plt.show()

# %%
## basic round 64 or 32 scatter
rounds_64_32_winner_df = winner_df[winner_df['round'].isin(['Round of 64', 'Round of 32'])]
rounds_64_32_scatter_title = 'Rounds of 64 and 32 Score Differential vs Seed Diff'
create_all_games_scatter(rounds_64_32_winner_df, rounds_64_32_scatter_title, 'n')
plt.show()

# %%
## basic all games scatter
title = 'Score Differential vs Seed Diff'
create_all_games_scatter(winner_df, title, 'y')
plt.show()

# %%
## basic round 64 scatter
round_64_winner_df = winner_df[winner_df['round'] == 'Round of 64']
round_64_scatter_title = 'Round of 64 Score Differential vs Seed Diff'
create_all_games_scatter(round_64_winner_df, round_64_scatter_title, 'y')
plt.show()

# %%
## basic round 64 or 32 scatter
rounds_64_32_winner_df = winner_df[winner_df['round'].isin(['Round of 64', 'Round of 32'])]
rounds_64_32_scatter_title = 'Rounds of 64 and 32 Score Differential vs Seed Diff'
create_all_games_scatter(rounds_64_32_winner_df, rounds_64_32_scatter_title, 'y')
plt.show()

# %%
def create_score_diff_average_scatter(winner_df, title, absolute, median_mean_mode):
    if absolute == 'y':
        seed_diff_measure = 'abs_seed_diff'
    elif absolute == 'n':
        seed_diff_measure = 'seed_diff'
    seed_diff_groupby = winner_df[[seed_diff_measure, 'score_diff']].groupby(seed_diff_measure)
    mean_seed_score_df = seed_diff_groupby.agg(median_mean_mode)
    mean_seed_score_df.reset_index(inplace=True)
    plt.scatter(mean_seed_score_df[seed_diff_measure], mean_seed_score_df['score_diff'])
    plt.xlabel(seed_diff_measure.replace('_', ' '))
    plt.ylabel('average point diff')
    plt.title(title)

# %%
title = 'Average Score Differential vs Seed Diff'
create_score_diff_average_scatter(winner_df,
                                  'Average Score Differential vs Seed Diff',
                                  'n',
                                  'median')
plt.show()

# %%
round_64_winner_df = winner_df[winner_df['round'] == 'Round of 64']
round_64_scatter_title = 'Round of 64 Score Differential vs Seed Diff'
create_score_diff_average_scatter(round_64_winner_df,
                                  round_64_scatter_title,
                                  'n',
                                  'median')
plt.show()

# %%
rounds_64_32_winner_df = winner_df[winner_df['round'].isin(['Round of 64', 'Round of 32'])]
rounds_64_32_scatter_title = 'Rounds of 64 and 32 Score Differential vs Seed Diff'
create_score_diff_average_scatter(rounds_64_32_winner_df,
                                  rounds_64_32_scatter_title,
                                  'n',
                                  'median')
plt.show()

# %%
title = 'Average Score Differential vs Seed Diff'
create_score_diff_average_scatter(winner_df,
                                  'Average Score Differential vs Seed Diff',
                                  'n',
                                  'median')
plt.show()

# %%
round_64_winner_df = winner_df[winner_df['round'] == 'Round of 64']
round_64_scatter_title = 'Round of 64 Score Differential vs Seed Diff'
create_score_diff_average_scatter(round_64_winner_df, round_64_scatter_title, 'y', 'median')
plt.show()

# %%
rounds_64_32_winner_df = winner_df[winner_df['round'].isin(['Round of 64', 'Round of 32'])]
rounds_64_32_scatter_title = 'Rounds of 64 and 32 Score Differential vs Seed Diff'
create_score_diff_average_scatter(rounds_64_32_winner_df,
                                  rounds_64_32_scatter_title,
                                  'y',
                                  'median')
plt.show()

# %%
## basic all games scatter
title = 'Score Differential vs Seed Diff'
create_all_games_scatter(winner_df, title, 'n')
create_score_diff_average_scatter(winner_df, title, 'n', 'mean')
plt.show()

# %%
## basic round 64 scatter
round_64_winner_df = winner_df[winner_df['round'] == 'Round of 64']
round_64_scatter_title = 'Round of 64 Score Differential vs Seed Diff'
create_all_games_scatter(round_64_winner_df, round_64_scatter_title, 'n')
create_score_diff_average_scatter(round_64_winner_df, round_64_scatter_title, 'n', 'mean')

plt.show()

# %%
## basic round 64 or 32 scatter
rounds_64_32_winner_df = winner_df[winner_df['round'].isin(['Round of 64', 'Round of 32'])]
rounds_64_32_scatter_title = 'Rounds of 64 and 32 Score Differential vs Seed Diff'
create_all_games_scatter(rounds_64_32_winner_df, rounds_64_32_scatter_title, 'n')
create_score_diff_average_scatter(rounds_64_32_winner_df,
                                  rounds_64_32_scatter_title,
                                  'n',
                                  'median')
plt.show()

# %%
## basic all games scatter
title = 'Score Differential vs Seed Diff'
create_all_games_scatter(winner_df, title, 'y')
create_score_diff_average_scatter(winner_df,
                                  title,
                                  'y',
                                  'median')
plt.show()

# %%
## basic round 64 scatter
round_64_winner_df = winner_df[winner_df['round'] == 'Round of 64']
round_64_scatter_title = 'Round of 64 Score Differential vs Seed Diff'
create_all_games_scatter(round_64_winner_df, round_64_scatter_title, 'y')
create_score_diff_average_scatter(round_64_winner_df,
                                  round_64_scatter_title,
                                  'y',
                                  'median')
plt.show()

# %%
## basic round 64 or 32 scatter
rounds_64_32_winner_df = winner_df[winner_df['round'].isin(['Round of 64', 'Round of 32'])]
rounds_64_32_scatter_title = 'Rounds of 64 and 32 Score Differential vs Seed Diff'
create_all_games_scatter(rounds_64_32_winner_df, rounds_64_32_scatter_title, 'y')
create_score_diff_average_scatter(rounds_64_32_winner_df,
                                  rounds_64_32_scatter_title,
                                  'y',
                                  'median')
plt.show()

# %%
## basic round 64 scatter
round_64_winner_df = winner_df[winner_df['round'] == 'Round of 64']
round_64_scatter_title = 'Round of 64 Score Differential vs Seed Diff'
create_all_games_scatter(round_64_winner_df, round_64_scatter_title, 'y')
create_score_diff_average_scatter(round_64_winner_df,
                                  round_64_scatter_title,
                                  'y',
                                  'mean')

plt.show()

# %%
## basic round 64 scatter
round_64_winner_df = winner_df[winner_df['round'] == 'Round of 64']
round_64_scatter_title = 'Round of 64 Score Differential vs Seed Diff'
create_all_games_scatter(round_64_winner_df, round_64_scatter_title, 'n')
create_score_diff_average_scatter(round_64_winner_df,
                                  round_64_scatter_title,
                                  'n',
                                  'median')

plt.show()
